# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
factbook = pd.io.parsers.read_csv("factbook.csv", ";")
factbook
# Out:
#             Country Area(sq km) Birth rate(births/1000 population)  \
# 0            String      double                             double
# 1       Afghanistan      647500                              47.02
# 2          Akrotiri         123                                NaN
# 3           Albania       28748                              15.08
# 4           Algeria     2381740                              17.13
# ..              ...         ...                                ...
# 259       West Bank        5860                              32.37
# 260  Western Sahara      266000                                NaN
# 261           Yemen      527970                              43.07
# 262          Zambia      752614                              41.38
# 263        Zimbabwe      390580                              29.74
#
#     Current account balance Death rate(deaths/1000 population)  \
# 0                    double                             double
# ...

# %%
factbook = factbook.dropna().iloc[1:]
factbook
# Out:
#             Country Area(sq km) Birth rate(births/1000 population)  \
# 16          Austria       83870                               8.81
# 49            Chile      756950                              15.44
# 50            China     9596960                              13.14
# 64   Czech Republic       78866                               9.07
# 65          Denmark       43094                              11.36
# 96           Greece      131940                               9.72
# 112         Hungary       93030                               9.76
# 115       Indonesia     1919440                              20.71
# 118         Ireland       70280                              14.47
# 120           Italy      301230                               8.89
# 127          Jordan       92300                              21.76
# 129      Kazakhstan     2717300                              15.78
# 160          Mexico     1972550                              21.01
# ...

# %%
fig, ax = plt.subplots()
ax.set_xlabel("GDP - per capita")
ax.set_ylabel("Life expectancy at birth(years)")
ax.scatter(factbook['GDP - per capita'].astype(int), factbook['Life expectancy at birth(years)'].astype(float))

# %%
r = LinearRegression()
#r.fit(factbook['GDP - per capita'].astype(int), factbook['Life expectancy at birth(years)'].astype(float))

# %%
from sklearn.preprocessing import scale

# %%
X = scale(factbook['Life expectancy at birth(years)'])
y = scale(factbook['GDP - per capita'])

# %%
print(X)
print(y)
#r.fit(X, y)
# Out:
# [ 0.87374962  0.26027514 -0.86967144  0.11346074  0.53293046  0.91831827
#  -0.83558952 -1.5775266   0.51720035  1.07299774  0.69547498 -2.36927571
#  -0.10413919  0.80558579 -1.48838929 -0.30863068  1.03105076  0.73217858]
# [ 1.38478622 -0.64879291 -1.15225182 -0.04661657  1.47363191  0.39761189
#  -0.23417969 -1.35955843  1.44401668  1.02940346 -1.260841   -0.93507347
#  -0.75738209  0.58517501 -1.21148228 -0.52046025  0.59504675  1.21696659]

# %%
print(X.reshape(-1, 1))
# Out:
# [[ 0.87374962]
#  [ 0.26027514]
#  [-0.86967144]
#  [ 0.11346074]
#  [ 0.53293046]
#  [ 0.91831827]
#  [-0.83558952]
#  [-1.5775266 ]
#  [ 0.51720035]
#  [ 1.07299774]
#  [ 0.69547498]
#  [-2.36927571]
#  [-0.10413919]
#  [ 0.80558579]
#  [-1.48838929]
#  [-0.30863068]
#  [ 1.03105076]
#  [ 0.73217858]]

# %%
r.fit(X.reshape(-1, 1), y)
# Out:
# LinearRegression()

# %%
pred = r.predict(X.reshape(-1, 1))

# %%
print(pred)
# Out:
# [ 0.61829264  0.18417886 -0.6154068   0.08028838  0.37711832  0.64983082
#  -0.59128936 -1.11630732  0.36598719  0.75928686  0.49213992 -1.67657383
#  -0.07369216  0.57005778 -1.05323096 -0.21839675  0.72960387  0.51811254]

# %%
fig, ax = plt.subplots()
ax.set_xlabel("GDP - per capita")
ax.set_ylabel("Life expectancy at birth(years)")
ax.scatter(X.inverse_transform(y_new), y)
ax.plot(X, pred, color='blue', linewidth=3)

# %%
X_array = factbook['Life expectancy at birth(years)'].astype(float).array
print(X_array)
mean_of_array = X_array.mean(axis=0)
std_of_array = X_array.std(axis=0)
print(mean_of_array)
print(std_of_array)
# Out:
# <PandasArray>
# [78.92, 76.58, 72.27, 76.02, 77.62, 79.09,  72.4, 69.57, 77.56, 79.68, 78.24,
#  66.55, 75.19, 78.66, 69.91, 74.41, 79.52, 78.38]
# Length: 18, dtype: float64
# 75.58722222222224
# 3.924923087377646

# %%
X_scale = scale(X_array)
print(X_scale)
X_original = (X_scale * std_of_array) + mean_of_array
print(X_original)
# Out:
# [ 0.87374962  0.26027514 -0.86967144  0.11346074  0.53293046  0.91831827
#  -0.83558952 -1.5775266   0.51720035  1.07299774  0.69547498 -2.36927571
#  -0.10413919  0.80558579 -1.48838929 -0.30863068  1.03105076  0.73217858]
# [79.01662226 76.60878213 72.17382872 76.03254688 77.6789333  79.19155082
#  72.30759761 69.39555164 77.61719381 79.79865581 78.31690804 66.28799727
#  75.17848393 78.74908447 69.74540875 74.37587055 79.63401717 78.46096685]
